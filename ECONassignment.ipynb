# %%
Data Cleaning
# Out:
#   Cell In[3], line 1
#     Data Cleaning
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv('ECONTRADE.csv')

# %%
Data.head()
# Out:
#                    Provinces   ID  Year  \
# 0  Newfoundland and Labrador  1.0  2007
# 1  Newfoundland and Labrador  1.0  2008
# 2  Newfoundland and Labrador  1.0  2009
# 3  Newfoundland and Labrador  1.0  2010
# 4  Newfoundland and Labrador  1.0  2011
#
#   Interprovincial exports of total products  \
# 0                                  8,718.00
# 1                                  9,087.00
# 2                                  5,553.70
# 3                                  7,363.00
# 4                                  8,804.50
#
#   International exports of total products
# 0                               11,966.70
# 1                               15,114.30
# 2                                9,253.00
# 3                               10,748.10
# 4                               13,345.40

# %%
Data = Data.dropna()

# %%
Data
# Out:
#                      Provinces   ID  Year  \
# 0    Newfoundland and Labrador  1.0  2007
# 1    Newfoundland and Labrador  1.0  2008
# 2    Newfoundland and Labrador  1.0  2009
# 3    Newfoundland and Labrador  1.0  2010
# 4    Newfoundland and Labrador  1.0  2011
# ..                         ...  ...   ...
# 135           British Columbia  9.0  2016
# 136           British Columbia  9.0  2017
# 137           British Columbia  9.0  2018
# 138           British Columbia  9.0  2019
# 139           British Columbia  9.0  2020
#
#     Interprovincial exports of total products  \
# 0                                    8,718.00
# 1                                    9,087.00
# 2                                    5,553.70
# 3                                    7,363.00
# 4                                    8,804.50
# ..                                        ...
# 135                                 39,377.60
# 136                                 40,736.80
# ...

# %%
BCdata = pd.DataFrame(Data['Provinces']=="British Columbia")

# %%
Data['Provinces'].unique()
# Out:
# array(['Newfoundland and Labrador', 'Prince Edward Island', 'Nova Scotia',
#        'New Brunswick', 'Quebec', 'Ontario', 'Manitoba', 'Saskatchewan',
#        'Alberta', 'British Columbia'], dtype=object)

# %%
BC = Data.query('Provinces == "British Columbia"')
NewFondland = Data.query('Provinces == "Newfoundland and Labrador"')
PEI = Data.query('Provinces == "Prince Edward Island"')
Ontario = Data.query('Provinces == "Ontario"')
Manitoba = Data.query('Provinces == "Manitoba"')
Saskatchewan = Data.query('Provinces == "Saskatchewan"')
Alberta = Data.query('Provinces == "Alberta"')
Quebec = Data.query('Provinces == "Quebec"')
NewBrunswick = Data.query('Provinces == "New Brunswick"')

# %%
sns.lineplot(BC['International exports of total products'])
# Out:
# <Axes: ylabel='International exports of total products'>

# %%
plt
sns.lineplot(data=Data,y=Data['International exports of total products'],x=Data['Year'],hue=Data['Provinces'])
# Out:
# <Axes: xlabel='Year', ylabel='International exports of total products'>

# %%
sns.pairplot(Data, hue=Data['Provinces'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/b1/58gn_xfd2jl121wl3xj_47y80000gn/T/ipykernel_34551/2281672366.py in ?()
# ----> 1 sns.pairplot(Data, hue=Data['Provinces'])
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/axisgrid.py in ?(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2115             diag_kind = "hist" if kind == "hist" else "kde"
#    2116
#    2117     # Set up the PairGrid
#    2118     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                     hue_order=hue_order, palette=palette, corner=corner,
#    2121                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
# ...
